# %%
# %matplotlib inline
import sys, os, time
import numpy as np
import matplotlib.pyplot as plt
import scipy.io
import cv2

# %%
def humansize(nbytes):
    '''From https://stackoverflow.com/questions/14996453/python-libraries-to-calculate-human-readable-filesize-from-bytes'''
    suffixes = ['B', 'KB', 'MB', 'GB', 'TB', 'PB']
    i = 0
    while nbytes >= 1024 and i < len(suffixes)-1:
        nbytes /= 1024.
        i += 1
    f = ('%.2f' % nbytes).rstrip('0').rstrip('.')
    return '%s %s' % (f, suffixes[i])

# %% [markdown]
# ## Preprocess images

# %%
fns = os.listdir("data/val")
fns.sort()
fns = [
    "data/val/" + fn
    for ind, fn in enumerate(fns) if ind<100
]

# %%
x_val1 = np.zeros((len(fns), 224, 224, 3), dtype=np.float32)
print(humansize(x_val1.nbytes))
# Out:
# 57.42 MB

# %%
# %%time

img = cv2.imread(fns[0])

height, width, _ = img.shape
new_height = height * 256 // min(img.shape[:2])
new_width = width * 256 // min(img.shape[:2])
img = cv2.resize(img, (new_width, new_height), interpolation=cv2.INTER_CUBIC)

# Crop
height, width, _ = img.shape
startx = width//2 - (224//2)
starty = height//2 - (224//2)
img = img[starty:starty+224,startx:startx+224]
assert img.shape[0] == 224 and img.shape[1] == 224, (img.shape, height, width)

x_val1[0,:,:,:] = img[:,:,::-1]

plt.figure()
plt.imshow(x_val1[0] / 255.0)
plt.show()
plt.close()
# Out:
# CPU times: user 539 ms, sys: 14.1 ms, total: 553 ms
# Wall time: 140 ms

# %%
# %%time

for i in range(len(fns)):
    #print("%d/%d" % (i, len(fns)))
    
    # Load (as BGR)
    img = cv2.imread(fns[i])
    
    # Resize
    height, width, _ = img.shape
    new_height = height * 256 // min(img.shape[:2])
    new_width = width * 256 // min(img.shape[:2])
    img = cv2.resize(img, (new_width, new_height), interpolation=cv2.INTER_CUBIC)
    
    # Crop
    height, width, _ = img.shape
    startx = width//2 - (224//2)
    starty = height//2 - (224//2)
    img = img[starty:starty+224,startx:startx+224]
    assert img.shape[0] == 224 and img.shape[1] == 224, (img.shape, height, width)
    
    # Save (as RGB)
    x_val1[i,:,:,:] = img[:,:,::-1]
# Out:
# CPU times: user 443 ms, sys: 70.4 ms, total: 513 ms
# Wall time: 556 ms

# %% [markdown]
# ### Save all

# %%
# %%time

np.save("data/x_val_1000.npy", x_val1)
# Out:
# CPU times: user 5.52 ms, sys: 172 ms, total: 178 ms
# Wall time: 181 ms

# %% [markdown]
# ### Save in chunks

# %%
for i in range(0,1000,100):
    np.save("data/x_val_%d_%d.npy" % (i, i+100), x_val[i:i+100])

# %% [markdown]
# ## Mapping between different label types

# %%
meta = scipy.io.loadmat("data/meta.mat")
original_idx_to_synset = {}
synset_to_name = {}

for i in range(1000):
    ilsvrc2012_id = int(meta["synsets"][i,0][0][0][0])
    synset = meta["synsets"][i,0][1][0]
    name = meta["synsets"][i,0][2][0]
    original_idx_to_synset[ilsvrc2012_id] = synset
    synset_to_name[synset] = name

synset_to_keras_idx = {}
keras_idx_to_name = {}
f = open("data/synset_words.txt","r")
idx = 0
for line in f:
    parts = line.split(" ")
    synset_to_keras_idx[parts[0]] = idx
    keras_idx_to_name[idx] = " ".join(parts[1:])
    idx += 1
f.close()

def convert_original_idx_to_keras_idx(idx):
    return synset_to_keras_idx[original_idx_to_synset[idx]]

# %%
f = open("data/ILSVRC2012_validation_ground_truth.txt","r")
y_val = f.read().strip().split("\n")
y_val = list(map(int, y_val))
y_val = np.array([convert_original_idx_to_keras_idx(idx) for idx in y_val])
f.close()

# %%
np.save("data/y_val.npy", y_val)

# %% [markdown]
# ## Show example images

# %%
for i in range(2):
    plt.figure()
    plt.imshow(x_val[i] / 255.0)
    plt.title(keras_idx_to_name[y_val[i]])
    plt.show()
    plt.close()
